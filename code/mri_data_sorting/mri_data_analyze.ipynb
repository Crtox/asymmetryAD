# %% [markdown]
# ## Analyzing patients' data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
loadPath = "../data/"
savePath = "../results/"

# %% [markdown]
# ### Frequency of visits per patient

# %%
df = pd.read_csv(loadPath + 'MRIT1_UDS_matched_final.csv')

# Count the occurrences of each patient (NACCID) in the dataset
naccid_counts = df['NACCID'].value_counts()

# Count how many patients have 2 scans, 3 scans, and so on
scan_frequency = naccid_counts.value_counts().sort_index()

# Printing the results
print(scan_frequency)
print('Total number of patients with more than one MRIT1 scan =', np.sum(scan_frequency.values))
# Out:
# count
# 2    738
# 3    223
# 4     44
# 5      5
# 6      5
# 7      3
# 8      3
# 9      1
# Name: count, dtype: int64
# Total number of patients with more than one MRIT1 scan = 1022

# %% [markdown]
# ### Visualizing data

# %%
plt.figure(figsize=(8, 5))
plt.bar(scan_frequency.index, scan_frequency.values, color='blue')
plt.title('Number of Patients with longitudinal MRIT1 data', fontsize=16)
plt.xlabel('Number of Scans', fontsize=14)
plt.ylabel('Number of Patients', fontsize=14)
plt.xticks(scan_frequency.index)                                          
plt.grid(axis='y')

textstr = f"Total patients with >1 scan: {np.sum(scan_frequency.values)}"

plt.gca().text(0.95, 0.95, textstr, transform=plt.gca().transAxes, fontsize=12,
               verticalalignment='top', horizontalalignment='right'
               )
               #bbox=dict(facecolor='white', edgecolor='black', boxstyle='round', pad=0.5)

#plt.savefig(savePath + 'MRIT1_UDS_matched_patients_number_histogram.png')
plt.show()

# %% [markdown]
# ## Analyzing data by cognitive status
# I have NACCIDs stored by the patients' cognitive status <br>
# (1=normal cognition, 2=impaired-not MCI, 3=mild cognitive impairment, 4=demented)

# %% [markdown]
# Loading the .txt file. Each row represents one possible cognition status (constant or change).

# %%
# Open the .txt file and read lines into arrays
with open(loadPath + 'naccids_by_uds_categories_matched_final.txt', 'r') as f:
    lines = f.readlines()

# %%
constant_1_array = [x for x in lines[0].strip().split(',') if x]
constant_2_array = [x for x in lines[1].strip().split(',') if x]
constant_3_array = [x for x in lines[2].strip().split(',') if x]
constant_4_array = [x for x in lines[3].strip().split(',') if x]
change_1_2_array = [x for x in lines[4].strip().split(',') if x]
change_1_3_array = [x for x in lines[5].strip().split(',') if x]
change_1_4_array = [x for x in lines[6].strip().split(',') if x]
change_1_2_3_array = [x for x in lines[7].strip().split(',') if x]
change_1_2_4_array = [x for x in lines[8].strip().split(',') if x]
change_1_3_4_array = [x for x in lines[9].strip().split(',') if x]
change_1_2_3_4_array = [x for x in lines[10].strip().split(',') if x]
change_2_3_array = [x for x in lines[11].strip().split(',') if x]
change_2_4_array = [x for x in lines[12].strip().split(',') if x]
change_2_3_4_array = [x for x in lines[13].strip().split(',') if x]
change_3_4_array = [x for x in lines[14].strip().split(',') if x]

# %%
print(constant_2_array)
# Out:
# ['NACC052272', 'NACC185770']

# %% [markdown]
# Sanity check: checking the total count of all patients to see if I covered all of them.

# %%
total_count = (
    len(constant_1_array) + len(constant_2_array) + len(constant_3_array) + len(constant_4_array) +
    len(change_1_2_array) + len(change_1_3_array) + len(change_1_4_array) +
    len(change_1_2_3_array) + len(change_1_2_4_array) + len(change_1_3_4_array) +
    len(change_1_2_3_4_array) + len(change_2_3_array) + len(change_2_4_array) +
    len(change_2_3_4_array) + len(change_3_4_array)
)

print(f"Total number of NACCIDs across all categories: {total_count}")
# Out:
# Total number of NACCIDs across all categories: 1022

# %%
print(len(constant_1_array))
# Out:
# 648

# %% [markdown]
# Visualizing by UDSD.

# %%
category_lengths = {
    "Constant 1": len(constant_1_array),
    "Constant 2": len(constant_2_array),
    "Constant 3": len(constant_3_array),
    "Constant 4": len(constant_4_array),
    "Change 1->2": len(change_1_2_array),
    "Change 1->3": len(change_1_3_array),
    "Change 1->4": len(change_1_4_array),
    "Change 1->2->3": len(change_1_2_3_array),
    "Change 1->2->4": len(change_1_2_4_array),
    "Change 1->3->4": len(change_1_3_4_array),
    "Change 1->2->3->4": len(change_1_2_3_4_array),
    "Change 2->3": len(change_2_3_array),
    "Change 2->4": len(change_2_4_array),
    "Change 2->3->4": len(change_2_3_4_array),
    "Change 3->4": len(change_3_4_array)
}

# Prepare data for histogram
labels = list(category_lengths.keys())
values = list(category_lengths.values())

# Plot the histogram
plt.figure(figsize=(12, 6))
plt.bar(labels, values, color='blue')
plt.xlabel('NACCUDSD Categories', fontsize=15)
plt.ylabel('Frequency of Patients', fontsize=15)
plt.title('Frequency of Patients with MRIT1 longitudinal data in Each NACCUDSD Category', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()
plt.grid(axis='y')

textstr = (
    "1: normal cognition\n"
    "2: impaired-not MCI\n"
    "3: MCI (mild cognitive impairment)\n"
    "4: demented"
)

plt.gca().text(0.7, 0.8, textstr, transform=plt.gca().transAxes, fontsize=12,
               verticalalignment='center', horizontalalignment='right',
               bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

#plt.savefig(savePath + 'MRIT1_patients_number_by_udsd_histogram_matched_final.png')
plt.show()

# %% [markdown]
# ## Plotting longitudinal data
# I want to visualize how many MRIT1 scans each patient has and what the time gap between each scan is.

# %%
loadPath = '../data/'

# Load the CSV file
df = pd.read_csv(loadPath + 'MRIT1_UDS_matched_final.csv')

# %%
patients = df['NACCID'].unique()

number_of_scans = len(df['NACCID'])

# %% [markdown]
# I over complicated when writing this code. What it does is creates an array that stores subarray. Each unique patients get its own subarray, which containts time intervals from the first MRIT1 scan.

# %%
from dateutil import parser

differences = []
sum = 0                                                      # sum to store indexing of the patients (borders for what dates to read)

for i in range(0, len(patients)):                            # one subarray for each unique NACCID (patient)

    naccid = df['NACCID'].unique()[i]                        # unique patients

    num = naccid_counts.loc['{}'.format(naccid)]             # number of MRIT1 scans


    months = np.array(df['MRIMO'][sum : sum + num])
    day = np.array(df['MRIDY'][sum : sum + num])
    years = np.array(df['MRIYR'][sum : sum + num])


    diffs = []


    date1 = np.zeros(num, dtype=object)


    for k in range(0, num):
        
        date1[k] = ('{}-{}-{}'.format(years[k], months[k], day[k]))
        
        date1[k] = parser.parse(date1[k])

        
    for l in range(0, len(date1), 1):
            
        d = np.abs(date1[l] - date1[0])
        

        diffs.append(d.days)

    sum += num

    differences.append(diffs)

# %% [markdown]
# Some sanity checks.

# %%
print(len(differences))
print(differences)
print(differences[0])
# Out:
# 1022
238591188, 74.54742583040378], 'NACC895414': [0.0, 12.71478792259421], 'NACC032898': [0.0, 7.85228504780366, 21.618424943325557], 'NACC006571': [0.0, 17.018760061766926], 'NACC937842': [0.0, 10.809212471662779], 'NACC531820': [0.0, 16.788776817688998, 35.450274337155435], 'NACC051936': [0.0, 54.0132076091599], 'NACC448698': [0.0, 28.32079377073956], 'NACC085853': [0.0, 21.125603706015703, 38.670039754246474], 'NACC758074': [0.0, 12.386240431054308], 'NACC138574': [0.0, 15.178894109143476, 35.9102408253113, 84.27243157998488, 91.66475013963269], 'NACC791165': [0.0, 18.43151427538851], 'NACC905058': [0.0, 13.897558892137859, 32.95331340145218, 85.88231428853041], 'NACC868237': [0.0, 19.548575746624174, 42.08693366626146, 64.88812957913066], 'NACC582717': [0.0, 21.946 ...

# %% [markdown]
# Sorting the dictionary by lenghts of value array and also by last element in value array.

# %%
sorted_items = sorted(dic_unsorted.items(), key=lambda x: (len(x[1]), x[1][-1]))          #, len(x[1])

# Rebuilding the dictionary manually
dic_sorted = {k: v for k, v in sorted_items}

# Display the sorted dictionary
print(dic_sorted)
# Out:
# {'NACC880879': [0.0, 5.092486118868482], 'NACC744056': [0.0, 5.2567598646384335], 'NACC664012': [0.0, 5.355324112100404], 'NACC420114': [0.0, 5.552452607024345], 'NACC871706': [0.0, 5.683871603640306], 'NACC290168': [0.0, 5.749581101948286], 'NACC781698': [0.0, 5.782435851102276], 'NACC961754': [0.0, 5.848145349410257], 'NACC372085': [0.0, 6.012419095180208], 'NACC937115': [0.0, 6.439530834182081], 'NACC110647': [0.0, 6.800933074875973], 'NACC055588': [0.0, 6.866642573183953], 'NACC932960': [0.0, 6.866642573183953], 'NACC802042': [0.0, 7.0637710681078945], 'NACC464247': [0.0, 7.753720800341689], 'NACC150980': [0.0, 7.786575549495679], 'NACC901146': [0.0, 8.049413542727601], 'NACC461456': [0.0, 8.772218024115386], 'NACC425139': [0.0, 9.199329763117259], 'NACC354797': [0.0, 9.232184512271248], 'NACC683064': [0.0, 9.265039261425239], 'NACC988332': [0.0, 9.46216775634918], 'NACC189763': [0.0, 9.65929625127312], 'NACC518995': [0.0, 9.65929625127312], 'NACC208765': [0.0, 9.856424746197062], 'NACC540978': [0.0, 9.987843742813023], 'NACC247936': [0.0, 10.053553241121003], 'NACC326999': [0.0, 10.119262739428985], 'NACC216121': [0.0, 10.119262739428985], 'NACC287146': [0.0, 10.184972237736964], 'NACC000531': [0.0, 10.283536485198935], 'NACC115470': [0.0, 10.480664980122876], 'NACC421012': [0.0, 10.579229227584847], 'NACC598236': [0.0, 10.743502973354799], 'NACC478776': [0.0, 10.809212471662779], 'NACC937842': [0.0, 10.809212471662779], 'NACC049968': [0.0, 10.809212471662779], 'NACC922188': [0.0, 10.84206722081677], 'NACC403422': [0.0, 10.84206722081677], 'NACC694714': [0.0, 10.874921969970758], 'NACC799620': [0.0, 10.874921969970758], 'NACC848645': [0.0, 11.00634096658672], 'NACC711567': [0.0, 11.00634096658672], 'NACC657938': [0.0, 11.0720504648947], 'NACC616529': [0.0, 11.0720504648947], 'NACC098465': [0.0, 11.10490521404869], 'NACC570211': [0.0, 11.137759963202681], 'NACC265729': [0.0, 11.236324210664652], 'NACC089717': [0.0, 11.302033708972631], 'NACC923186': [0.0, 11.499162203896573], 'NACC986370': [0.0, 11.499162203896573], 'NACC429641': [0.0, 11.499162203896573], 'NACC063341': [0.0, 11.532016953050563], 'NACC057402': [0.0, 11.564871702204552], 'NACC238353': [0.0, 11.696290698820514], 'NACC508817': [0.0, 11.696290698820514], 'NACC960476': [0.0, 11.729145447974505], 'NACC737593': [0.0, 11.729145447974505], 'NACC469573': [0.0, 11.762000197128495], 'NACC557066': [0.0, 11.827709695436475], 'NACC923543': [0.0, 11.827709695436475], 'NACC649780': [0.0, 11.893419193744455], 'NACC905292': [0.0, 11.926273942898446], 'NACC915669': [0.0, 11.959128692052436], 'NACC762017': [0.0, 12.024838190360416], 'NACC269350': [0.0, 12.024838190360416], 'NACC686306': [0.0, 12.057692939514407], 'NACC143891': [0.0, 12.090547688668396], 'NACC178095': [0.0, 12.123402437822387], 'NACC226634': [0.0, 12.156257186976378], 'NACC762724': [0.0, 12.221966685284357], 'NACC999566': [0.0, 12.254821434438348], 'NACC589333': [0.0, 12.287676183592337], 'NACC305649': [0.0, 12.287676183592337], 'NACC758074': [0.0, 12.386240431054308], 'NACC154191': [0.0, 12.419095180208299], 'NACC034854': [0.0, 12.45194992936229], 'NACC828873': [0.0, 12.484804678516278], 'NACC951821': [0.0, 12.61622367513224], 'NACC972035': [0.0, 12.64907842428623], 'NACC726763': [0.0, 12.64907842428623], 'NACC755561': [0.0, 12.68193317344022], 'NACC106610': [0.0, 12.68193317344022], 'NACC895414': [0.0, 12.71478792259421], 'NACC097453': [0.0, 12.846206919210172], 'NACC733410': [0.0, 13.010480664980122], 'NACC529273': [0.0, 13.043335414134113], 'NACC560745': [0.0, 13.109044912442092], 'NACC665307': [0.0, 13.109044912442092], 'NACC185770': [0.0, 13.109044912442092], 'NACC010716': [0.0, 13.141899661596083], 'NACC685779': [0.0, 13.141899661596083], 'NACC242005': [0.0, 13.174754410750074], 'NACC838988': [0.0, 13.339028156520024], 'NACC052272': [0.0, 13.339028156520024], 'NACC565149': [0.0, 13.404737654828004], 'NACC205350': [0.0, 13.470447153135986], 'NACC988104': [0.0, 13.470447153135986], 'NACC344768': [0.0, 13.5 ...

# %% [markdown]
# Artificially creating y positions of each patient on the plot. My logic here is that each patient get their own unique constant y values, the patients with least amount of scans get highest y values (they will be on top of the plot), while those with most scans will have lowest y values (at the bottom of the plot).

# %%
y = []

m = len(patients)

for keys, values in dic_sorted.items():

    ones = (np.ones_like(values))

    y.append(ones * m)

    m -= 1

print(y)
print(len(y))
# Out:
# [array([1022., 1022.]), array([1021., 1021.]), array([1020., 1020.]), array([1019., 1019.]), array([1018., 1018.]), array([1017., 1017.]), array([1016., 1016.]), array([1015., 1015.]), array([1014., 1014.]), array([1013., 1013.]), array([1012., 1012.]), array([1011., 1011.]), array([1010., 1010.]), array([1009., 1009.]), array([1008., 1008.]), array([1007., 1007.]), array([1006., 1006.]), array([1005., 1005.]), array([1004., 1004.]), array([1003., 1003.]), array([1002., 1002.]), array([1001., 1001
plt.rc('xtick', labelsize=12)    # fontsize of the tick labels
plt.rc('ytick', labelsize=12)

# %%
# gettin some nice colors

import matplotlib.colors as mcolors
barve = mcolors.CSS4_COLORS

#barve_array = ['mediumorchid', 'darkviolet', 'blueviolet', 'royalblue', 'dodgerblue', 'deepskyblue', 'mediumseagreen', 'seagreen', 'mediumspringgreen', 'yellowgreen', 'gold', 'orange', 'orangered', 'red']
barve_array = ['mediumorchid', 'blueviolet', 'royalblue', 'seagreen', 'mediumspringgreen', 'yellowgreen', 'orange', 'orangered', 'red']

# %% [markdown]
# Data to plot on the x axis.

# %%
x_data = []

for values in dic_sorted.values():

    x_data.append(values)

# %% [markdown]
# Finding out which patient has 19 years in between its scans :o

# %%
# [0.0, 228.96474685415777] is the time interval of the scans

target_value = [0.0, 228.96474685415777]

# Find the key corresponding to the target value
key_for_value = next((k for k, v in dic_sorted.items() if v == target_value), None)

# Display the key
print(key_for_value)
# Out:
# NACC861625

# %%
plt.figure(figsize=(10, 10))

for i in range(0, len(y)):

    for j in range(0, len(y[i])):

        plt.scatter(x_data[i][j], y[i][j], color=barve[barve_array[j]], s=4)

plt.title('MRIT1 longitudinal data', fontsize=15)
plt.xlabel('Time interval between i-th scan and 1st scan [month]', fontsize=12)
plt.ylabel('Patients', fontsize=12)
plt.yticks([])

plt.savefig(savePath + 'MRIT1_long_data_interval_matcched_final.png')
plt.show()

# %% [markdown]
# ## Analyzing data in sorted cohorts

# %% [markdown]
# ### Frequency by categories

# %%
loadPath = "../../NACC_data/sorted_cohorts/"
savePath = "../results/sorted_cohorts/"

# %%
nc_df = pd.read_csv(loadPath + 'nc_v3.csv')
mci_df = pd.read_csv(loadPath + 'mci_v3.csv')
alz_df = pd.read_csv(loadPath + 'alzd_v3.csv')
trans_df = pd.read_csv(loadPath + 'trans_v3.csv')

# %%
nc_naccid_counts = nc_df['NACCID'].value_counts()
mci_naccid_counts = mci_df['NACCID'].value_counts()
alz_naccid_counts = alz_df['NACCID'].value_counts()
trans_naccid_counts = trans_df['NACCID'].value_counts()

# %%
nc_scan_frequency = nc_naccid_counts.value_counts().sort_index()
mci_scan_frequency = mci_naccid_counts.value_counts().sort_index()
alz_scan_frequency = alz_naccid_counts.value_counts().sort_index()
trans_scan_frequency = trans_naccid_counts.value_counts().sort_index()

# %%
combined_naccid_counts = pd.concat([nc_naccid_counts, 
                                    mci_naccid_counts, 
                                    alz_naccid_counts, 
                                    trans_naccid_counts])

combined_scan_frequency = combined_naccid_counts.value_counts().sort_index()

# %%
nc_number_of_patients = np.sum(nc_scan_frequency.values)
mci_number_of_patients = np.sum(mci_scan_frequency.values)
alz_number_of_patients = np.sum(alz_scan_frequency.values)
trans_number_of_patients = np.sum(trans_scan_frequency.values)
combined_number_of_patients = np.sum(combined_scan_frequency.values)

# %%
print(trans_scan_frequency)
print('Total number of patients with more than one MRIT1 scan =', trans_number_of_patients)
# Out:
# count
# 2    66
# 3    32
# 4     6
# 5     2
# 6     4
# 8     1
# Name: count, dtype: int64
# Total number of patients with more than one MRIT1 scan = 111

# %%
plt.figure(figsize=(8, 5))
plt.bar(mci_scan_frequency.index, mci_scan_frequency.values, color='blue')
plt.title('Number of MCI patients with longitudinal MRIT1 data', fontsize=16)
plt.xlabel('Number of scans', fontsize=14)
plt.ylabel('Number of patients', fontsize=14)
plt.xticks(mci_scan_frequency.index)                                          
plt.grid(axis='y')

textstr = f'Total patients with >1 scan: {mci_number_of_patients}\n'

min_scans = 2
max_scans = mci_scan_frequency.index.max() 

for scans in range(min_scans, max_scans + 1):
    count = mci_scan_frequency.get(scans, 0)
    textstr += f'Patients with {scans} scans: {count}\n'

plt.gca().text(0.95, 0.95, textstr, transform=plt.gca().transAxes, fontsize=12,
               verticalalignment='top', horizontalalignment='right',
               bbox=dict(facecolor='white', edgecolor='black', boxstyle='round', pad=0.5))

#plt.savefig(savePath + 'mci_histogram.png')
plt.show()

# %% [markdown]
# ### Frequency by uds scores for transition patients

# %%
txtPath = "../data/"

# %%
with open(txtPath + 'trans_uds_categories.txt', 'r') as f:
    lines = f.readlines()

# %%
constant_1_array = [x for x in lines[0].strip().split(',') if x]
constant_2_array = [x for x in lines[1].strip().split(',') if x]
constant_3_array = [x for x in lines[2].strip().split(',') if x]
constant_4_array = [x for x in lines[3].strip().split(',') if x]
change_1_2_array = [x for x in lines[4].strip().split(',') if x]
change_1_3_array = [x for x in lines[5].strip().split(',') if x]
change_1_4_array = [x for x in lines[6].strip().split(',') if x]
change_1_2_3_array = [x for x in lines[7].strip().split(',') if x]
change_1_2_4_array = [x for x in lines[8].strip().split(',') if x]
change_1_3_4_array = [x for x in lines[9].strip().split(',') if x]
change_1_2_3_4_array = [x for x in lines[10].strip().split(',') if x]
change_2_3_array = [x for x in lines[11].strip().split(',') if x]
change_2_4_array = [x for x in lines[12].strip().split(',') if x]
change_2_3_4_array = [x for x in lines[13].strip().split(',') if x]
change_3_4_array = [x for x in lines[14].strip().split(',') if x]

# %%
print(constant_3_array)
print(constant_4_array)
# Out:
# ['NACC356689', 'NACC389033', 'NACC594813', 'NACC685779']
# ['NACC665307', 'NACC851285']

# %%
category_lengths = {
    "Constant 3 but\n" 
    "ALZD change 0-->1": len(constant_3_array),
    "Constant 4 but\n" 
    "ALZD change 0-->1": len(constant_4_array),
    "Change 1-->3": len(change_1_3_array),
    "Change 1-->4": len(change_1_4_array),
    "Change 1-->3-->4": len(change_1_3_4_array),
    "Change 2-->3": len(change_2_3_array),
    "Change 2-->4": len(change_2_4_array),
    "Change 2-->3-->4": len(change_2_3_4_array),
    "Change 3-->4": len(change_3_4_array)
}

# Prepare data for histogram
labels = list(category_lengths.keys())
values = list(category_lengths.values())

# Plot the histogram
plt.figure(figsize=(12, 6))
plt.bar(labels, values, color='blue')
plt.xlabel('NACCUDSD Categories', fontsize=15)
plt.ylabel('Frequency of Patients', fontsize=15)
plt.title('Frequency of transition patients with MRIT1 longitudinal data in Each NACCUDSD Category', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()
plt.grid(axis='y')

textstr = (
    "1: normal cognition\n"
    "2: impaired-not MCI\n"
    "3: MCI (mild cognitive impairment)\n"
    "4: demented \n"
    "ALZD 0: non-Alzheimer's \n"
    "ALZD 1: Alzheimer's \n"
)

plt.gca().text(0.7, 0.75, textstr, transform=plt.gca().transAxes, fontsize=12,
               verticalalignment='center', horizontalalignment='right',
               bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

#plt.savefig(savePath + 'trans_udsd_histogram.png')
plt.show()

# %% [markdown]
# ### Longitudinal data for each cohort

# %%
from dateutil import parser

# %%
nc_df = pd.read_csv(loadPath + 'nc_v3.csv')
mci_df = pd.read_csv(loadPath + 'mci_v3.csv')
alz_df = pd.read_csv(loadPath + 'alzd_v3.csv')
trans_df = pd.read_csv(loadPath + 'trans_v3.csv')

combined_df = pd.concat([nc_df, mci_df, alz_df, trans_df], ignore_index=True)

# %%
nc_naccid_counts = nc_df['NACCID'].value_counts()
mci_naccid_counts = mci_df['NACCID'].value_counts()
alz_naccid_counts = alz_df['NACCID'].value_counts()
trans_naccid_counts = trans_df['NACCID'].value_counts()

combined_naccid_counts = combined_df['NACCID'].value_counts()

# %%
patients = trans_df['NACCID'].unique()

number_of_scans = len(mci_df['NACCID'])

# %%
differences = []
sum = 0                                                         # sum to store indexing of the patients (borders for what dates to read)

for i in range(0, len(patients)):                               # one subarray for each unique NACCID (patient)

    naccid = trans_df['NACCID'].unique()[i]                        # unique patients

    num = trans_naccid_counts.loc['{}'.format(naccid)]             # number of MRIT1 scans


    months = np.array(trans_df['MRIMO'][sum : sum + num])
    day = np.array(trans_df['MRIDY'][sum : sum + num])
    years = np.array(trans_df['MRIYR'][sum : sum + num])


    diffs = []


    date1 = np.zeros(num, dtype=object)


    for k in range(0, num):
        
        date1[k] = ('{}-{}-{}'.format(years[k], months[k], day[k]))
        
        date1[k] = parser.parse(date1[k])

        
    for l in range(0, len(date1), 1):
            
        d = np.abs(date1[l] - date1[0])
        

        diffs.append(d.days)

    sum += num

    differences.append(diffs)

# %%
for p in differences:

    for e in range(0, len(p)):

        p[e] = p[e] / 30.437

# %%
dic_unsorted = {}

for i in range(0, len(patients)):    
    
    dic_unsorted['{}'.format(patients[i])] = differences[i]

# %%
sorted_items = sorted(dic_unsorted.items(), key=lambda x: (len(x[1]), x[1][-1]))          #, len(x[1])

dic_sorted = {k: v for k, v in sorted_items}

print(dic_sorted)
# Out:
# {'NACC461456': [0.0, 8.772218024115386], 'NACC425139': [0.0, 9.199329763117259], 'NACC683064': [0.0, 9.265039261425239], 'NACC326999': [0.0, 10.119262739428985], 'NACC287146': [0.0, 10.184972237736964], 'NACC265729': [0.0, 11.236324210664652], 'NACC057402': [0.0, 11.564871702204552], 'NACC226634': [0.0, 12.156257186976378], 'NACC665307': [0.0, 13.109044912442092], 'NACC685779': [0.0, 13.141899661596083], 'NACC483045': [0.0, 13.207609159904063], 'NACC565149': [0.0, 13.404737654828004], 'NACC613244': [0.0, 13.536156651443966], 'NACC463825': [0.0, 13.700430397213916], 'NACC364698': [0.0, 13.897558892137859], 'NACC358181': [0.0, 14.554653875217662], 'NACC120068': [0.0, 14.620363373525642], 'NACC747160': [0.0, 14.718927620987612], 'NACC307886': [0.0, 15.835989092223281], 'NACC175569': [0.0, 16.854486315996976], 'NACC981684': [0.0, 17.248743305844858], 'NACC112837': [0.0, 17.248743305844858], 'NACC192548': [0.0, 17.31445280415284], 'NACC221012': [0.0, 17.938693038078654], 'NACC369503': [0.0, 18.102966783848604], 'NACC692365': [0.0, 19.515720997470183], 'NACC778651': [0.0, 19.811413739856096], 'NACC790740': [0.0, 20.43565397378191], 'NACC527327': [0.0, 21.552715445017576], 'NACC127753': [0.0, 22.04553668232743], 'NACC730340': [0.0, 23.096888655255118], 'NACC254862': [0.0, 23.85254788579689], 'NACC702644': [0.0, 24.1482406281828], 'NACC960818': [0.0, 24.181095377336792], 'NACC606998': [0.0, 24.181095377336792], 'NACC402140': [0.0, 24.969609357032557], 'NACC497997': [0.0, 25.26530209941847], 'NACC219592': [0.0, 25.36386634688044], 'NACC594813': [0.0, 25.495285343496402], 'NACC431902': [0.0, 25.725268587574334], 'NACC650436': [0.0, 26.250944574038176], 'NACC389033': [0.0, 26.54663731642409], 'NACC271933': [0.0, 26.645201563886058], 'NACC693324': [0.0, 26.74376581134803], 'NACC273411': [0.0, 29.470709991129215], 'NACC401286': [0.0, 29.503564740283206], 'NACC985565': [0.0, 29.503564740283206], 'NACC450406': [0.0, 31.474849689522618], 'NACC891081': [0.0, 32.821894404836215], 'NACC276544': [0.0, 32.854749153990205], 'NACC356689': [0.0, 36.46877156092913], 'NACC241217': [0.0, 37.68439727962677], 'NACC838157': [0.0, 39.359989486480266], 'NACC934040': [0.0, 44.71531359858067], 'NACC750813': [0.0, 44.94529684265861], 'NACC880514': [0.0, 45.99664881558629], 'NACC883907': [0.0, 48.62502874790551], 'NACC615997': [0.0, 48.92072149029142], 'NACC214789': [0.0, 50.037782961527085], 'NACC188574': [0.0, 54.3746098498538], 'NACC688621': [0.0, 56.67444229063311], 'NACC759297': [0.0, 58.74429148733449], 'NACC312721': [0.0, 61.14268817557578], 'NACC114717': [0.0, 65.90662680290436], 'NACC422130': [0.0, 70.37487268784703], 'NACC838773': [0.0, 90.67910766501298], 'NACC419496': [0.0, 7.359463810493806, 13.831849393829877], 'NACC781621': [0.0, 7.589447054571738, 24.345369123106742], 'NACC950415': [0.0, 11.137759963202681, 24.90389985872458], 'NACC783403': [0.0, 18.234385780464564, 30.883464204750794], 'NACC146825': [0.0, 21.946972434865458, 34.33321286591977], 'NACC531820': [0.0, 16.788776817688998, 35.450274337155435], 'NACC107329': [0.0, 11.926273942898446, 36.33735256431317], 'NACC714081': [0.0, 9.429313007195189, 36.764464303315044], 'NACC514308': [0.0, 21.618424943325557, 37.22443079147091], 'NACC878209': [0.0, 24.411078621414724, 37.22443079147091], 'NACC305496': [0.0, 20.008542234780037, 38.440056510168546], 'NACC965510': [0.0, 9.166475013963268, 38.60433025593849], 'NACC973860': [0.0, 22.866905411177186, 38.83431350001643], 'NACC191311': [0.0, 27.170877550349903, 41.16700068994973], 'NACC181584': [0.0, 23.75398363833492, 41.42983868318165], 'NACC131953': [0.0, 13.634720898905936, 42.08693366626146], 'NACC916290': [0.0, 15.178894109143476, 42.31691691033939], 'NACC015713': [0.0, 16.723067319381016, 42.84259289680323], 'NACC613344': [0.0, 26.87518480796399, 43.9596543680389], 'NACC376036': [0.0, 26.448073068962117, 46.88372704274403], 'NACC663649': [0.0, 21.421296448401616, 48.066498012287674], 'NACC036265': [0.0, 23.58970989256497, 50.694877944606894], ' ...

# %%
y = []

m = len(patients)

for keys, values in dic_sorted.items():

    ones = (np.ones_like(values))

    y.append(ones * m)

    m -= 1

print(y)
print(len(y))
# Out:
# [array([111., 111.]), array([110., 110.]), array([109., 109.]), array([108., 108.]), array([107., 107.]), array([106., 106.]), array([105., 105.]), array([104., 104.]), array([103., 103.]), array([102., 102.]), array([101., 101.]), array([100., 100.]), array([99., 99.]), array([98., 98.]), array([97., 97.]), array([96., 96.]), array([95., 95.]), array([94., 94.]), array([93., 93.]), array([92., 92.]), array([91., 91.]), array([90., 90.]), array([89., 89.]), array([88., 88.]), array([87., 87.]), array([86., 86.]), array([85., 85.]), array([84., 84.]), array([83., 83.]), array([82., 82.]), array([81., 81.]), array([80., 80.]), array([79., 79.]), array([78., 78.]), array([77., 77.]), array([76., 76.]), array([75., 75.]), array([74., 74.]), array([73., 73.]), array([72., 72.]), array([71., 71.]), array([70., 70.]), array([69., 69.]), array([68., 68.]), array([67., 67.]), array([66., 66.]), array([65., 65.]), array([64., 64.]), array([63., 63.]), array([62., 62.]), array([61., 61.]), array([60., 60.]), array([59., 59.]), array([58., 58.]), array([57., 57.]), array([56., 56.]), array([55., 55.]), array([54., 54.]), array([53., 53.]), array([52., 52.]), array([51., 51.]), array([50., 50.]), array([49., 49.]), array([48., 48.]), array([47., 47.]), array([46., 46.]), array([45., 45., 45.]), array([44., 44., 44.]), array([43., 43., 43.]), array([42., 42., 42.]), array([41., 41., 41.]), array([40., 40., 40.]), array([39., 39., 39.]), array([38., 38., 38.]), array([37., 37., 37.]), array([36., 36., 36.]), array([35., 35., 35.]), array([34., 34., 34.]), array([33., 33., 33.]), array([32., 32., 32.]), array([31., 31., 31.]), array([30., 30., 30.]), array([29., 29., 29.]), array([28., 28., 28.]), array([27., 27., 27.]), array([26., 26., 26.]), array([25., 25., 25.]), array([24., 24., 24.]), array([23., 23., 23.]), array([22., 22., 22.]), array([21., 21., 21.]), array([20., 20., 20.]), array([19., 19., 19.]), array([18., 18., 18.]), array([17., 17., 17.]), array([16., 16., 16.]), array([15., 15., 15.]), array([14., 14., 14.]), array([13., 13., 13., 13.]), array([12., 12., 12., 12.]), array([11., 11., 11., 11.]), array([10., 10., 10., 10.]), array([9., 9., 9., 9.]), array([8., 8., 8., 8.]), array([7., 7., 7., 7., 7.]), array([6., 6., 6., 6., 6.]), array([5., 5., 5., 5., 5., 5.]), array([4., 4., 4., 4., 4., 4.]), array([3., 3., 3., 3., 3., 3.]), array([2., 2., 2., 2., 2., 2.]), array([1., 1., 1., 1., 1., 1., 1., 1.])]
# 111

# %%
plt.rc('xtick', labelsize=12)    # fontsize of the tick labels
plt.rc('ytick', labelsize=12)

# %%
import matplotlib.colors as mcolors
barve = mcolors.CSS4_COLORS

barve_array = ['mediumorchid', 'blueviolet', 'royalblue', 'seagreen', 'mediumspringgreen', 'orange', 'orangered', 'red']

# %%
x_data = []

for values in dic_sorted.values():

    x_data.append(values)

# %%
plt.figure(figsize=(10, 10))

for i in range(0, len(y)):

    for j in range(0, len(y[i])):

        plt.scatter(x_data[i][j], y[i][j], color=barve[barve_array[j]], s=4)

plt.title('Transition patients\' MRIT1 longitudinal data', fontsize=15)
plt.xlabel('Time interval between i-th scan and 1st scan [month]', fontsize=12)
plt.ylabel('Patients', fontsize=12)
plt.yticks([])

#plt.savefig(savePath + 'trans_longitudinal.png')
plt.show()
